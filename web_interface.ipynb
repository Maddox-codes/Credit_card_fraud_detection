# %%
import joblib

model_path = "E:/carr/btech cse/computer/machine learning/credit card fraud detection/best_fraud_detection_model.joblib"
loaded_model = joblib.load(model_path)

# %%
import streamlit as st

st.title("Credit Card Fraud Detection Application")
st.write("This application simulates a credit card fraud detection system. Enter the transaction details below to predict if a transaction is fraudulent.")
# Out:
# 2025-07-25 14:40:35.808 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.935
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-07-25 14:40:35.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
feature_names = [f'V{i}' for i in range(1, 29)] + ['Time', 'Amount']

input_data = {}
st.subheader("Enter Transaction Details")

for feature in feature_names:
    if feature == 'Time':
        input_data[feature] = st.number_input(f"Enter {feature} (in seconds since the first transaction)", value=0.0, format="%.2f")
    elif feature == 'Amount':
        input_data[feature] = st.number_input(f"Enter {feature} (Transaction Amount)", value=0.0, format="%.2f")
    else:
        input_data[feature] = st.number_input(f"Enter {feature}", value=0.0, format="%.6f")
# Out:
# 2025-07-25 14:40:35.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.953 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.955 Session state does not function when running a script without `streamlit run`
# 2025-07-25 14:40:35.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.959 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:35.998 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.004 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.020 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.040 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.071 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.071 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:40:36.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import pandas as pd

all_expected_features = [f'V{i}' for i in range(1, 29)] + ['Time', 'Amount'] + [f'dummy_V{i}' for i in range(29, 34)]

input_df = pd.DataFrame([input_data])

for dummy_feature in [f'dummy_V{i}' for i in range(29, 34)]:
    input_df[dummy_feature] = 0.0

try:
    input_df = input_df[all_expected_features]
except KeyError as e:
    st.error(f"Error: Missing expected feature during reordering: {e}")
    input_df = None

if input_df is not None:
    
    prediction = loaded_model.predict(input_df)

   
    prediction_result = prediction[0]

    st.subheader("Prediction Result")
    if prediction_result == 1:
        st.write("Prediction: Fraudulent Transaction")
    else:
        st.write("Prediction: Not Fraudulent Transaction")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# 2025-07-25 14:41:08.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:41:08.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:41:08.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:41:08.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:41:08.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:41:08.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
st.subheader("Prediction Result")
if prediction_result == 1:
    st.write("Prediction: Fraudulent Transaction")
else:
    st.write("Prediction: Not Fraudulent Transaction")
# Out:
# 2025-07-25 14:41:12.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:41:12.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:41:12.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:41:12.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:41:12.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:41:12.892 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
st.subheader("Beyond Simulation: Real-Time Fraud Detection")
st.write("""
This application simulates a batch prediction scenario where you input transaction details and get an immediate prediction. A real-world fraud detection system operates in real-time to analyze transactions as they occur.

Here's how a more advanced, real-time system might work:

*   **Real-time Processing:** Transactions are processed instantly as they happen, rather than waiting for a user to manually input details.
*   **Message Queues:** Systems often use message queues (like Kafka or RabbitMQ) to handle the high volume and velocity of incoming transactions. Transactions are published to a queue, and the fraud detection service consumes them for analysis.
*   **Low-Latency Models:** The prediction model needs to be highly optimized for low-latency inference to provide a quick decision.
*   **Feedback Loop:** User feedback (e.g., a customer confirming a transaction was legitimate despite a fraud alert) is crucial for model improvement. This feedback can be used to retrain or fine-tune the model, making it more accurate over time. Data scientists continuously monitor model performance and retrain as needed with new data and feedback.
*   **Alerting and Action:** Based on the real-time prediction, the system can trigger alerts (e.g., to the customer or a fraud analyst) or take immediate action (e.g., temporarily block the transaction).
""")
# Out:
# 2025-07-25 14:41:15.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:41:15.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:41:15.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:41:15.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:41:15.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-25 14:41:15.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# %%writefile 'E:/carr/btech cse/computer/machine learning/credit card fraud detection/app.py'
# import streamlit as st
# import joblib
# import pandas as pd
# import os
#
#
# MODEL_FILENAME = "best_fraud_detection_model.joblib"
# MODEL_PATH = os.path.join('/content/drive/My Drive/Colab Notebooks/credit card fraud detection/best_fraud_detection_model.joblib', MODEL_FILENAME)
#
# @st.cache_resource
# def load_model(path):
#     """
#     Loads the trained model from the specified path.
#     Uses st.cache_resource to load the model only once.
#     """
#     if not os.path.exists(path):
#         st.error(f"Error: Model file not found at '{path}'.")
#         st.error("Please ensure the model file is in the correct location.")
#         st.stop()
#     try:
#         loaded_model = joblib.load(path)
#         return loaded_model
#     except Exception as e:
#         st.error(f"An error occurred while loading the model: {e}")
#         st.stop()
#
# ALL_EXPECTED_FEATURES = [f'V{i}' for i in range(1, 29)] + ['Time', 'Amount'] + [f'dummy_V{i}' for i in range(29, 34)]
#
#
# st.set_page_config(layout="wide")
# st.title("💳 Credit Card Fraud Detection")
# st.write(
#     "This application uses a pre-trained machine learning model to predict "
#     "whether a credit card transaction is fraudulent. Fill in the details below."
# )
#
# model = load_model(MODEL_PATH)
#
# input_data = {}
#
# st.header("Enter Transaction Details")
#
# with st.form("transaction_form"):
#
#     col1, col2, col3 = st.columns(3)
#     columns = [col1, col2, col3]
#
#     feature_index = 0
#     for feature in ALL_EXPECTED_FEATURES:
#         if 'dummy' in feature:
#             input_data[feature] = 0.0
#             continue
#
#         target_col = columns[feature_index % 3]
#
#         label = feature
#         help_text = None
#         if feature == 'Time':
#             label = "Time"
#             help_text = "Seconds elapsed between this transaction and the first transaction in the dataset."
#         elif feature == 'Amount':
#             label = "Transaction Amount"
#             help_text = "The monetary value of the transaction."
#         else:
#             help_text = f"Anonymized feature: {feature}"
#
#         input_data[feature] = target_col.number_input(
#             label=label,
#             value=0.0,
#             format="%.4f",
#             key=feature,
#             help=help_text
#         )
#         feature_index += 1
#
#     submitted = st.form_submit_button("Predict Fraud")
#
# if submitted and model is not None:
#     input_df = pd.DataFrame([input_data])
#
#     try:
#         input_df = input_df[ALL_EXPECTED_FEATURES]
#
#         prediction = model.predict(input_df)
#
#         if hasattr(model, "predict_proba"):
#             prediction_proba = model.predict_proba(input_df)
#             fraud_confidence = prediction_proba[0][1]
#         else:
#             fraud_confidence = None
#
#         st.header("Prediction Result")
#         if prediction[0] == 1:
#             st.error("🚨 Prediction: Fraudulent Transaction")
#             if fraud_confidence is not None:
#                 st.metric(label="Confidence Score (Fraud)", value=f"{fraud_confidence:.2%}")
#         else:
#             st.success("✅ Prediction: Not a Fraudulent Transaction")
#             if fraud_confidence is not None:
#                  st.metric(label="Confidence Score (Not Fraud)", value=f"{prediction_proba[0][0]:.2%}")
#
#         with st.expander("View Input Data"):
#             st.dataframe(input_df)
#
#     except KeyError as e:
#         st.error(f"Error: A feature mismatch occurred. The model expected a feature that was not provided. Details: {e}")
#     except Exception as e:
#         st.error(f"An error occurred during prediction: {e}")
#
#
# st.info(
#     """
#     **Disclaimer:** This is a simulator and should not be used for actual financial decisions.
#     The accuracy of the prediction depends entirely on the quality and characteristics of the model it was trained on.
#     """,
#     icon="ℹ️"
# )
#
# st.subheader("Beyond Simulation: Real-Time Fraud Detection")
# st.markdown("""
# This application simulates a scenario where you manually input transaction details for a prediction. In a real-world setting, fraud detection systems are fully automated and operate in real-time. Here's how they typically work:
#
# * **Real-time Processing:** Transactions are analyzed instantly as they occur, without manual data entry.
# * **Message Queues:** High-volume systems use message queues (like Apache Kafka or RabbitMQ) to handle the massive stream of incoming transactions reliably.
# * **Low-Latency Models:** The machine learning models are highly optimized for speed to provide decisions in milliseconds.
# * **Feedback Loop:** The system continuously improves. When a transaction is flagged and a customer confirms it was legitimate (or vice-versa), this feedback is used to retrain and fine-tune the model, making it more accurate over time.
# * **Automated Actions:** Based on the real-time prediction, the system can trigger alerts to a fraud analyst or take immediate action, such as temporarily blocking the transaction and notifying the customer.
# """)
# Out:
# Writing /content/drive/My Drive/Colab Notebooks/credit card fraud detection /app.py
